# %%
# Import Dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint

# Create Paths for CSV Files

renewables_df_path = "CSV_Data/renewables_data.csv"
renewables_df = pd.read_csv(renewables_df_path)

natural_gas_df_path = "CSV_Data/natural_gas_data.csv"
natural_gas_df = pd.read_csv(natural_gas_df_path)

petroleum_df_path = "CSV_Data/petroleum_data.csv"
petroleum_df = pd.read_csv(petroleum_df_path)

nuclear_df_path = "CSV_Data/nuclear_data.csv"
nuclear_df = pd.read_csv(nuclear_df_path)

coal_df_path = "CSV_Data/coal_data.csv"
coal_df = pd.read_csv(coal_df_path)

# %%
renewables_df
# Out:
#    State Consumption
# 0     AK      15,100
# 1     AL     232,522
# 2     AR      88,219
# 3     AZ     102,430
# 4     CA     881,980
# 5     CO     121,106
# 6     CT      38,999
# 7     DC       2,596
# 8     DE       7,202
# 9     FL     300,693
# 10    GA     286,775
# 11    HI      20,641
# 12    IA     417,911
# 13    ID      86,220
# 14    IL     245,149
# 15    IN     170,310
# 16    KS     152,546
# 17    KY      80,976
# 18    LA     133,469
# 19    MA      75,053
# 20    MD      48,003
# 21    ME     101,763
# 22    MI     200,309
# 23    MN     230,364
# 24    MO     101,807
# 25    MS      65,275
# 26    MT      68,479
# 27    NC     192,198
# 28    ND      97,751
# 29    NE     168,639
# 30    NH      39,952
# 31    NJ      64,998
# 32    NM      82,042
# 33    NV      73,314
# 34    NY     270,685
# 35    OH     144,632
# 36    OK     188,573
# 37    OR     247,484
# 38    PA     184,808
# 39    RI      10,914
# 40    SC     143,051
# 41    SD     130,007
# ...

# %%
renewables_df['Consumption'] = renewables_df['Consumption'].str.replace(',', '').astype(int)

top_5_renewable_states = renewables_df['Consumption'].nlargest(5)


top_5_renewable_states
# Out:
# 4     881980
# 43    742759
# 47    426074
# 12    417911
# 9     300693
# Name: Consumption, dtype: int64

# %%
x_axis1 = ["California", "Texas", "Washington", "Iowa", "Florida"]
y_axis1 = [881.98, 742.76, 426.07, 417.91, 300.69]

plt.bar(x_axis1, y_axis1, color='darkseagreen', edgecolor='k')
plt.xlabel("U.S. States")
plt.xticks(rotation = 45)
plt.ylabel("Renewable Energy Consumed (Trillion Btu)")
plt.title("Total Renewable Energy Consumed by Top 5 Consuming States (2022)")
# Out:
# Text(0.5, 1.0, 'Total Renewable Energy Consumed by Top 5 Consuming States (2022)')

# %%
natural_gas_df
# Out:
#    State Consumption
# 0     AK     437,918
# 1     AL     787,240
# 2     AR     397,703
# 3     AZ     468,038
# 4     CA   2,130,928
# 5     CO     524,717
# 6     CT     307,213
# 7     DC      30,174
# 8     DE      89,673
# 9     FL   1,659,688
# 10    GA     812,417
# 11    HI         159
# 12    IA     433,720
# 13    ID     141,924
# 14    IL   1,136,906
# 15    IN     913,397
# 16    KS     318,000
# 17    KY     402,532
# 18    LA   2,073,687
# 19    MA     432,442
# 20    MD     310,134
# 21    ME      62,559
# 22    MI   1,087,609
# 23    MN     533,873
# 24    MO     322,545
# 25    MS     622,170
# 26    MT      93,952
# 27    NC     747,186
# 28    ND     193,250
# 29    NE     198,669
# 30    NH      60,113
# 31    NJ     754,990
# 32    NM     302,014
# 33    NV     302,315
# 34    NY   1,402,247
# 35    OH   1,421,845
# 36    OK     782,248
# 37    OR     297,591
# 38    PA   1,936,578
# 39    RI      93,830
# 40    SC     361,250
# 41    SD     103,234
# ...

# %%
natural_gas_df['Consumption'] = natural_gas_df['Consumption'].str.replace(',', '').astype(int)

top_5_gas_states = natural_gas_df['Consumption'].nlargest(5)


top_5_gas_states
# Out:
# 43    4977359
# 4     2130928
# 18    2073687
# 38    1936578
# 9     1659688
# Name: Consumption, dtype: int64

# %%
x_axis2 = ['Texas', 'California', 'Louisiana', 'Pennsylvania', 'Florida']
y_axis2 = [4977.36, 2130.93, 2073.69, 1936.58, 1659.69]

plt.bar(x_axis2, y_axis2, color='darksalmon', edgecolor='k')
plt.xlabel("U.S. States")
plt.xticks(rotation = 45)
plt.ylabel("Natural Gas Consumed (Trillion Btu)")
plt.title("Total Natural Gas Consumed by Top 5 Consuming States (2022)")
# Out:
# Text(0.5, 1.0, 'Total Natural Gas Consumed by Top 5 Consuming States (2022)')

# %%
petroleum_df
# Out:
#    State Consumption
# 0     AK     252,426
# 1     AL     576,648
# 2     AR     325,510
# 3     AZ     609,015
# 4     CA   3,044,716
# 5     CO     568,895
# 6     CT     303,272
# 7     DC      17,967
# 8     DE     111,870
# 9     FL   1,810,592
# 10    GA     938,628
# 11    HI     241,865
# 12    IA     424,480
# 13    ID     189,192
# 14    IL   1,140,091
# 15    IN     696,340
# 16    KS     344,999
# 17    KY     578,324
# 18    LA   1,655,108
# 19    MA     526,752
# 20    MD     410,668
# 21    ME     166,354
# 22    MI     822,203
# 23    MN     573,224
# 24    MO     603,901
# 25    MS     382,022
# 26    MT     175,966
# 27    NC     903,357
# 28    ND     169,624
# 29    NE     236,247
# 30    NH     148,648
# 31    NJ     768,649
# 32    NM     253,897
# 33    NV     302,230
# 34    NY   1,319,918
# 35    OH   1,031,381
# 36    OK     519,316
# 37    OR     319,172
# 38    PA   1,104,618
# 39    RI      78,989
# 40    SC     494,203
# 41    SD     118,120
# ...

# %%
petroleum_df['Consumption'] = petroleum_df['Consumption'].str.replace(',', '').astype(int)

top_5_petrol_states = petroleum_df['Consumption'].nlargest(5)


top_5_petrol_states
# Out:
# 43    6572661
# 4     3044716
# 9     1810592
# 18    1655108
# 34    1319918
# Name: Consumption, dtype: int64

# %%
x_axis3 = [' Texas', ' California', ' Florida', ' Louisiana', 'New York']
y_axis3 = [6572.66, 3044.72, 1810.59, 1655.11, 1319.92]

plt.bar(x_axis3, y_axis3, color='skyblue', edgecolor='k')
plt.xlabel("U.S. States")
plt.xticks(rotation = 45)
plt.ylabel("Petroleum Consumed (Trillion Btu)")
plt.title("Total Petroleum Consumed by Top 5 Consuming States (2022)")
# Out:
# Text(0.5, 1.0, 'Total Petroleum Consumed by Top 5 Consuming States (2022)')

# %%
nuclear_df
# Out:
#    State Consumption
# 0     AK           0
# 1     AL     441,289
# 2     AR     149,382
# 3     AZ     333,131
# 4     CA     183,480
# 5     CO           0
# 6     CT     171,705
# 7     DC           0
# 8     DE           0
# 9     FL     320,883
# 10    GA     355,353
# 11    HI           0
# 12    IA           0
# 13    ID           0
# 14    IL   1,031,111
# 15    IN           0
# 16    KS      93,673
# 17    KY           0
# 18    LA     168,582
# 19    MA           0
# 20    MD     154,461
# 21    ME           0
# 22    MI     271,293
# 23    MN     153,267
# 24    MO      92,555
# 25    MS      89,693
# 26    MT           0
# 27    NC     444,737
# 28    ND           0
# 29    NE      58,595
# 30    NH     113,901
# 31    NJ     295,337
# 32    NM           0
# 33    NV           0
# 34    NY     279,624
# 35    OH     175,487
# 36    OK           0
# 37    OR           0
# 38    PA     794,335
# 39    RI           0
# 40    SC     567,022
# 41    SD           0
# ...

# %%
nuclear_df['Consumption'] = nuclear_df['Consumption'].str.replace(',', '').astype(int)

top_5_nuclear_states = nuclear_df['Consumption'].nlargest(5)


top_5_nuclear_states
# Out:
# 14    1031111
# 38     794335
# 40     567022
# 27     444737
# 1      441289
# Name: Consumption, dtype: int64

# %%
x_axis4 = ['Illinois', ' Pennsylvania', 'South Carolina', 'North Carolina', 'Alabama']
y_axis4 = [1031.11, 794.34, 567.02, 444.74, 441.29]

plt.bar(x_axis4, y_axis4, color='thistle', edgecolor='k')
plt.xlabel("U.S. States")
plt.xticks(rotation = 45)
plt.ylabel("Nuclear Energy Consumed (Trillion Btu)")
plt.title("Total Nuclear Energy Consumed by Top 5 Consuming States (2022)")
# Out:
# Text(0.5, 1.0, 'Total Nuclear Energy Consumed by Top 5 Consuming States (2022)')

# %%
coal_df
# Out:
#    State Consumption
# 0     AK      18,615
# 1     AL     297,654
# 2     AR     211,724
# 3     AZ     154,007
# 4     CA      30,049
# 5     CO     233,256
# 6     CT           0
# 7     DC           0
# 8     DE       1,846
# 9     FL     171,953
# 10    GA     180,888
# 11    HI       7,680
# 12    IA     227,866
# 13    ID       1,881
# 14    IL     496,983
# 15    IN     719,238
# 16    KS     226,712
# 17    KY     523,276
# 18    LA      96,914
# 19    MA           0
# 20    MD      61,932
# 21    ME       1,269
# 22    MI     423,504
# 23    MN     184,517
# 24    MO     566,940
# 25    MS      66,214
# 26    MT     131,345
# 27    NC     163,029
# 28    ND     369,340
# 29    NE     223,571
# 30    NH       3,864
# 31    NJ       6,199
# 32    NM     138,077
# 33    NV      35,835
# 34    NY       6,143
# 35    OH     539,587
# 36    OK     106,855
# 37    OR       1,066
# 38    PA     435,540
# 39    RI           0
# 40    SC     150,973
# 41    SD      24,769
# ...

# %%
coal_df['Consumption'] = coal_df['Consumption'].str.replace(',', '').astype(int)

top_5_coal_states = coal_df['Consumption'].nlargest(5)


top_5_coal_states
# Out:
# 43    932569
# 15    719238
# 24    566940
# 35    539587
# 49    536642
# Name: Consumption, dtype: int64

# %%
x_axis5 = ['  Texas', 'Indiana', 'Missouri', 'Ohio', 'West Virginia']
y_axis5 = [932.57, 719.24, 566.94, 539.59, 536.64]

plt.bar(x_axis5, y_axis5, color='lightslategrey', edgecolor='k')
plt.xlabel("U.S. States")
plt.xticks(rotation = 45)
plt.ylabel("Coal Energy Consumed (Trillion Btu)")
plt.title("Total Coal Energy Consumed by Top 5 Consuming States (2022)")
# Out:
# Text(0.5, 1.0, 'Total Coal Energy Consumed by Top 5 Consuming States (2022)')

# %%
# Combined Bar Graphs

plt.bar(x_axis2, y_axis2, color='darksalmon', edgecolor='k')
plt.bar(x_axis3, y_axis3, color='skyblue', edgecolor='k')
plt.bar(x_axis4, y_axis4, color='thistle', edgecolor='k')
plt.bar(x_axis5, y_axis5, color='lightslategrey', edgecolor='k')

plt.xlabel("U.S. States")
plt.xticks(rotation = 90)
plt.ylabel("Energy Consumed (Trillion Btu)")
plt.ylim(0, 8000)
plt.title("Total Energy Consumed by Top 5 Consuming States by Nonrenewable Energy Type (2022)")
plt.legend(['Natural Gas', 'Petroleum', 'Nuclear', 'Coal'], loc='upper right')
