# %%
# Import Dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint

# Create Paths for CSV Files

renewables_df_path = "CSV_Data/renewables_data.csv"

renewables_df = pd.read_csv(renewables_data_path)

# %%
renewables_df
# Out:
#    State Consumption
# 0     AK      15,100
# 1     AL     232,522
# 2     AR      88,219
# 3     AZ     102,430
# 4     CA     881,980
# 5     CO     121,106
# 6     CT      38,999
# 7     DC       2,596
# 8     DE       7,202
# 9     FL     300,693
# 10    GA     286,775
# 11    HI      20,641
# 12    IA     417,911
# 13    ID      86,220
# 14    IL     245,149
# 15    IN     170,310
# 16    KS     152,546
# 17    KY      80,976
# 18    LA     133,469
# 19    MA      75,053
# 20    MD      48,003
# 21    ME     101,763
# 22    MI     200,309
# 23    MN     230,364
# 24    MO     101,807
# 25    MS      65,275
# 26    MT      68,479
# 27    NC     192,198
# 28    ND      97,751
# 29    NE     168,639
# 30    NH      39,952
# 31    NJ      64,998
# 32    NM      82,042
# 33    NV      73,314
# 34    NY     270,685
# 35    OH     144,632
# 36    OK     188,573
# 37    OR     247,484
# 38    PA     184,808
# 39    RI      10,914
# 40    SC     143,051
# 41    SD     130,007
# ...

# %%
renewables_df['Consumption'] = renewables_df['Consumption'].str.replace(',', '').astype(int)

top_5_states = renewables_df['Consumption'].nlargest(5)


top_5_states
# Out:
# 4     881980
# 43    742759
# 47    426074
# 12    417911
# 9     300693
# Name: Consumption, dtype: int64

# %%
x_axis = ["California", "Texas", "Washington", "Iowa", "Florida"]
y_axis = [881980, 742759, 426074, 417911, 300693]

plt.bar(x_axis, y_axis, color='darkseagreen', edgecolor='b')
plt.xlabel("U.S. States")
plt.ylabel("Renewable Energy Consumed (Billion Btu)")
plt.title("Total Renewable Energy Consumed by State (2022)")
# Out:
# Text(0.5, 1.0, 'Total Renewable Energy Consumed by State (2022)')
